# %% [markdown]
# # TrendTracker: Exploring Trending Youtube Videos in Canada

# %% [markdown]
# This notebook will take a look at video tags, to see which tags influence trending videos the most

# %% [markdown]
# ### Import Libraries and Data

# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt
from collections import Counter

# %%
# File name represents most recent update
file = r'/Users/OliverPan/Desktop/youtube_data/trend_12-03-20.csv'

# %%
trends = pd.read_csv(file)

# %%
trends.head()
# Out:
#       video_id                                              title  \
# 0  KX06ksuS6Xo  Diljit Dosanjh: CLASH (Official) Music Video |...
# 1  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 2  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 3  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 4  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
#
#             publishedAt                 channelId    channelTitle  categoryId  \
# 0  2020-08-11T07:30:02Z  UCZRdNleCgW-BGUJf-bbjzQg  Diljit Dosanjh          10
# 1  2020-08-11T16:34:06Z  UCYzPXprvl5Y-Sf0g4vX-m6g   jacksepticeye          24
# 2  2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A    Apex Legends          20
# 3  2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg        Brawadis          22
# 4  2020-08-11T15:10:05Z  UCDVPcEbVLQgLZX0Rt6jo34A        Mr. Kate          26
#
#           trending_date                                               tags  \
# 0  2020-08-12T00:00:00Z  clash diljit dosanjh|diljit dosanjh|diljit dos...
# 1  2020-08-12T00:00:00Z  jacksepticeye|funny|funny meme|memes|jacksepti...
# 2  2020-08-12T00:00:00Z  Apex Legends|Apex Legends characters|new Apex ...
# 3  2020-08-12T00:00:00Z  brawadis|prank|basketball|skits|ghost|funny vi...
# 4  2020-08-12T00:00:00Z  The LaBrant Family|DIY|Interior Design|Makeove...
#
#    view_count   likes  dislikes  comment_count  \
# 0     9140911  296541      6180          30059
# 1     2038853  353797      2628          40222
# 2     2381688  146740      2794          16549
# 3     1514614  156914      5857          35331
# 4     1123889   45803       964           2198
#
#                                    thumbnail_link  comments_disabled  \
# 0  https://i.ytimg.com/vi/KX06ksuS6Xo/default.jpg              False
# 1  https://i.ytimg.com/vi/J78aPJ3VyNs/default.jpg              False
# 2  https://i.ytimg.com/vi/M9Pmf9AB4Mo/default.jpg              False
# 3  https://i.ytimg.com/vi/3C66w5Z0ixs/default.jpg              False
# 4  https://i.ytimg.com/vi/VIUo6yapDbc/default.jpg              False
#
#    ratings_disabled                                        description
# 0             False  CLASH official music video performed by DILJIT...
# 1             False  I left youtube for a month and this is what ha...
# 2             False  While running her own modding shop, Ramya Pare...
# 3             False  SUBSCRIBE to BRAWADIS ▶ http://bit.ly/Subscrib...
# 4             False  Transforming The LaBrant Family's empty white ...

# %% [markdown]
# ### Looking at tags data

# %%
tags = trends[['tags']]

# %%
tags.head()
# Out:
#                                                 tags
# 0  clash diljit dosanjh|diljit dosanjh|diljit dos...
# 1  jacksepticeye|funny|funny meme|memes|jacksepti...
# 2  Apex Legends|Apex Legends characters|new Apex ...
# 3  brawadis|prank|basketball|skits|ghost|funny vi...
# 4  The LaBrant Family|DIY|Interior Design|Makeove...

# %%
#This represents all tags, split by '|', in an individual column
tags_split = tags['tags'].str.split("|",expand=True) 
tags_split
# Out:
#                          0                        1   \
# 0      clash diljit dosanjh           diljit dosanjh
# 1             jacksepticeye                    funny
# 2              Apex Legends  Apex Legends characters
# 3                  brawadis                    prank
# 4        The LaBrant Family                      DIY
# ...                     ...                      ...
# 22395                comedy            entertainment
# 22396     JYP Entertainment                      JYP
# 22397        clash of clans                      COC
# 22398           Fally Ipupa                  Bad Boy
# 22399                 쇼음악중심                     블랙맘바
#
#                               2                         3   \
# 0      diljit dosanjh goat album  diljit dosanjh new album
# 1                     funny meme                     memes
# 2                new Apex Legend      Apex Legends Rampart
# 3                     basketball                     skits
# 4                Interior Design                  Makeover
# ...                          ...                       ...
# 22395                 will smith                      will
# 22396                       ITZY                        있지
# 22397    Clash of Clans Gameplay   Clash of Clans Strategy
# 22398                    Musique                      Afro
# 22399                        에스파                       카리나
#
#                              4                          5   \
# 0            punjabi songs 2020           punjabi new song
# 1           jacksepticeye memes                     reddit
# 2         Apex Legends Season 6       Apex Legends Boosted
# 3                         ghost               funny videos
# 4                    Decorating          DIY Movie Theater
# ...                         ...                        ...
# 22395                     smith                     smiths
# 22396                ITZY Video                  ITZY Yeji
# 22397  Clash of Clans Animation  Clash of Clans Commercial
# 22398             Clip officiel                fally ipupa
# 22399                        지젤                         윈터
#
#                            6                         7   \
# 0               new song 2020       goat diljit dosanjh
# 1                   subreddit                 community
# 2                 Battle Pass      Season 6 Battle Pass
# 3                        vlog                  vlogging
# 4          Home Movie Theater             Movie Theater
# ...                       ...                       ...
# 22395               willsmith        will smith youtube
# 22396                ITZY Lia               ITZY Ryujin
# 22397  Clash of Clans Attacks  Clash of Clans Town Hall
# 22398            aya nakamura                 eloko oyo
# 22399                      닝닝                      음악중심
#
#                             8                      9   ...    69    70    71  \
# 0       the kidd punjabi music         the kidd music  ...  None  None  None
# 1              community memes    community subreddit  ...  None  None  None
# 2      Apex Legends new season      Apex Legends game  ...  None  None  None
# 3                          NBA               browadis  ...  None  None  None
# 4                    Stay Home           Cole LaBrant  ...  None  None  None
# ...                        ...                    ...  ...   ...   ...   ...
# 22395       youtube will smith     will smith channel  ...  None  None  None
# 22396          ITZY Chaeryeong              ITZY Yuna  ...  None  None  None
# 22397                Hog Rider                  PEKKA  ...  None  None  None
# 22398                    fally  fally ipupa eloko oyo  ...  None  None  None
# 22399                       음중                 쇼!음악중심  ...  None  None  None
#
#          72    73    74    75    76    77    78
# 0      None  None  None  None  None  None  None
# 1      None  None  None  None  None  None  None
# 2      None  None  None  None  None  None  None
# 3      None  None  None  None  None  None  None
# 4      None  None  None  None  None  None  None
# ...     ...   ...   ...   ...   ...   ...   ...
# 22395  None  None  None  None  None  None  None
# 22396  None  None  None  None  None  None  None
# 22397  None  None  None  None  None  None  None
# 22398  None  None  None  None  None  None  None
# 22399  None  None  None  None  None  None  None
#
# [22400 rows x 79 columns]

# %%
# Traverse through dataframe and place into dictionary
tags = []

for columns in tags_split.columns:
    for x in tags_split[columns].to_list():
        tags.append(x)

# %%
# Small sample of list
tags[0:10]
# Out:
# ['clash diljit dosanjh',
#  'jacksepticeye',
#  'Apex Legends',
#  'brawadis',
#  'The LaBrant Family',
#  'cgpgrey',
#  'bleacher report',
#  'tibo inshape',
#  '[None]',
#  'james']

# %%
# Remove None values
tags = [x for x in tags if x != '[None]']
tags = [x for x in tags if x is not None]

# %%
# Histogram from list
tag_count = dict(Counter(tags))

# %%
tag_count
# Out:
# {'clash diljit dosanjh': 6,
#  'jacksepticeye': 11,
#  'Apex Legends': 63,
#  'brawadis': 21,
#  'The LaBrant Family': 6,
#  'cgpgrey': 35,
#  'bleacher report': 36,
#  'tibo inshape': 23,
#  'james': 115,
#  'Professor injury': 6,
#  'xxl freshman': 50,
#  'JYP Entertainment': 58,
#  'chloe ting': 5,
#  'smosh': 54,
#  'barra': 5,
#  'farming': 9,
#  'R6': 9,
#  'CTV': 23,
#  'sharks': 5,
#  'portland trail blazers': 18,
#  'JuiceWRLD': 44,
#  'screenjunkies': 29,
#  'blaire white': 5,
#  'kylie jenner': 49,
#  'eleanor': 5,
#  'drawing': 48,
#  'faze rug': 47,
#  'the bachelor': 29,
#  'When Our Generation Gets Old and Hears a Throwback Song 5': 5,
#  'friendliest': 5,
#  'the ace family this is the end': 5,
#  'Merrell Twins': 34,
#  'college move in': 5,
#  'jack and gab': 5,
#  'unbox therapy': 60,
#  'DEATH BATTLE': 42,
#  'Vox.com': 14,
#  'Tampa Bay Lightning': 23,
#  'Hockey': 34,
#  'iann dior': 12,
#  'NLE Choppa': 45,
#  'NBA': 320,
#  'jeffree star': 75,
#  'Stephen Sharer': 5,
#  'Calgary Flames': 3,
#  'Selena Gomez': 36,
#  'uravgconsumer': 13,
#  'rasheed wallace': 5,
#  'taking': 11,
#  'video': 284,
#  'fox': 85,
#  'mcfly': 50,
#  'ufc': 225,
#  'uncle roger': 24,
#  'supermega': 8,
#  'movie': 81,
#  'Fifa': 12,
#  'avatar': 47,
#  'Joyca': 27,
#  'Cafe Chaos': 5,
#  'Football': 294,
#  'Eminem': 23,
#  'LeBron James': 94,
#  'note 20 ultra': 11,
#  'DaBaby': 53,
#  'Lil': 51,
#  'FAMM': 5,
#  'collin morikawa': 9,
#  'INOXTAG': 12,
#  'amazingphil': 9,
#  'binging with babish': 68,
#  'Cardi B': 59,
#  'Megan Thee Stallion': 53,
#  'Corse': 7,
#  'red bull': 15,
#  'People who think One Piece is the best anime': 5,
#  "Jeff's barbershop": 17,
#  'danandriya': 17,
#  'Swapping outfits with James charles': 10,
#  'hockey': 72,
#  'kyler and mad': 6,
#  'hayu': 12,
#  'denyzee': 34,
#  'neoxi': 17,
#  '2hype': 57,
#  'jianhao tan': 32,
#  'donut media': 17,
#  'baby registry': 4,
#  'minecraft': 101,
#  '88rising': 30,
#  'surprise': 80,
#  'crouton corse': 8,
#  'get 6 pack abs': 4,
#  'carli': 17,
#  'motorcycle road rage compilation': 4,
#  'memeulous': 4,
#  'Squeezie arnaque': 4,
#  'YG Entertainment': 98,
#  'Sky Sports': 23,
#  'simon': 83,
#  'sidemen': 139,
#  'Twinsthenewtrend': 6,
#  'Toronto Maple Leafs': 31,
#  'seb la frite': 19,
#  'super bike': 3,
#  'michou': 55,
#  'Winston-Salem': 3,
#  'worldstarhiphop': 3,
#  'dazn': 87,
#  'cloud': 3,
#  'samspedy': 7,
#  'Clash Royale': 27,
#  'BIGDAWSTV': 3,
#  'tifo football': 3,
#  'aquarium': 13,
#  'gift': 11,
#  'art': 59,
#  'impaulsive clips': 26,
#  'NBA on TNT': 40,
#  'latest News': 13,
#  'cole and sav': 10,
#  'tiny': 11,
#  "Cotard's syndrome": 2,
#  'carpentry': 6,
#  'machine gun kelly': 10,
#  'Beirut Explosion': 7,
#  'twice': 21,
#  'Telegraph': 9,
#  'joogsquad ppjt': 2,
#  'mtb': 37,
#  'funny': 1026,
#  'Fall Guys in a Nutshell': 2,
#  'president trump': 21,
#  'ijustine': 28,
#  'lucie': 12,
#  'Popcaan': 9,
#  'Jada Kingdom': 4,
#  'Knuckle Busters': 1,
#  'young don the sauce god': 1,
#  'Ashnikko': 1,
#  'Kane brown cool again': 1,
#  'Manchester United': 81,
#  'amixem': 49,
#  'DojaCattv': 1,
#  'TheKidLaroi': 7,
#  'cake rescue': 1,
#  'annoying orange': 18,
#  'BEIRUT': 1,
#  'viz media': 1,
#  'lebanon': 5,
#  'popcaan': 9,
#  'dr nozman': 28,
#  'COVID 19': 6,
#  'wedding proposal': 1,
#  'GLOW': 1,
#  'samsung galaxy note 20 ultra': 11,
#  'tomska': 15,
#  'Adobe Photoshop': 1,
#  'rod wave': 20,
#  'Latest Punjabi Songs 2020': 5,
#  'Entertainment': 143,
#  'biggest trash talker ever': 9,
#  'Donk': 15,
#  'Microsoft': 27,
#  'NFL': 86,
#  '라디오스타': 8,
#  'Rubirose': 4,
#  'taylormadegolf': 16,
#  'Lock': 10,
#  'Gunna': 18,
#  'do our parents approve of our engagement': 4,
#  'koffee': 13,
#  'Shay Mitchell': 4,
#  'franglish': 9,
#  'lexivee03': 4,
#  'Drake': 57,
#  'Robert Pattinson': 21,
#  'fortnite': 123,
#  'miley cyrus midnight sky': 37,
#  'rick and morty': 20,
#  'YoungBoy Never Broke Again': 26,
#  'Polo G martin and gina': 5,
#  'JohnLegend': 5,
#  "mcdonald's": 19,
#  'sewing': 44,
#  'surprising him with his dream car': 10,
#  'Machine': 14,
#  'Colin': 14,
#  'Shenseea': 11,
#  'reggae dancehall': 13,
#  'First we feast': 35,
#  'kaaris': 4,
#  'The CW': 8,
#  'Dana White schmo': 5,
#  'eddy burback': 36,
#  'burna boy': 27,
#  'illymation': 8,
#  'cosmonaut variety hour': 8,
#  '방탄소년단': 132,
#  'alicia keys ft. khalid': 5,
#  'Stage 2': 5,
#  'trey songz': 4,
#  'Food': 94,
#  'lemonade': 17,
#  'wrestling': 38,
#  'Barcelona reaction': 5,
#  'Nickelback': 6,
#  'Messi': 15,
#  'dua lipa': 19,
#  'katy perry': 31,
#  'p2': 5,
#  'dead by daylight': 38,
#  'Montreal Canadiens': 9,
#  'Vancouver Canucks': 27,
#  'Galaxy': 15,
#  'sm6 band': 4,
#  'Christina': 10,
#  'Watch': 8,
#  'Funny': 156,
#  'anthony alba': 4,
#  'ksi': 95,
#  'superheroes': 7,
#  'Summer walker': 3,
#  'RK': 3,
#  'rico nasty': 3,
#  'charli': 208,
#  'Soccer': 112,
#  'CBS': 50,
#  'nails': 51,
#  'VR': 18,
#  'ESPN MMA': 31,
#  'Sultaan': 7,
#  'Manchester City': 23,
#  'socassie': 5,
#  'engineering': 42,
#  'national': 5,
#  'nocomment': 4,
#  'mama rug': 9,
#  'reactions': 31,
#  'Stage 4': 3,
#  'catfish': 13,
#  'real life lore': 24,
#  'sean o malley': 11,
#  'Trump': 38,
#  'Music': 163,
#  'f2': 4,
#  'things to customize': 4,
#  'Tiwa': 3,
#  'The Late Late Show': 3,
#  'little': 7,
#  'OrvillePeck': 3,
#  'Pentatonix': 27,
#  'comedy': 894,
#  'The': 50,
#  'jaiden': 42,
#  'Asteroid': 7,
#  'ice': 28,
#  'bretman': 8,
#  't-series': 7,
#  'simonandmartina': 32,
#  'buzzfeed': 174,
#  'DIY': 120,
#  'do it yourself': 99,
#  'Dremacatcher': 7,
#  'Bandai Namco': 7,
#  'nikkietutorials robbed': 7,
#  'Fibre': 6,
#  'Smarter': 40,
#  'son': 10,
#  'emma chamberlain': 35,
#  'sean': 15,
#  'full day of eating': 12,
#  'nba': 237,
#  'animation': 466,
#  'blind': 10,
#  'squeezie mauvais design': 6,
#  'motogp': 6,
#  'the ddg family': 12,
#  'Spider-Man': 12,
#  'apple': 196,
#  'The United Stand': 58,
#  'vegan': 44,
#  'mi 10 ultra': 6,
#  'ashish chanchlani new': 5,
#  'Andi Eigenmann': 20,
#  'the kissing booth': 5,
#  'F1': 88,
#  'team alboe': 4,
#  'frozencrystal': 8,
#  'Olympique Lyonnais': 4,
#  'Custom & Performance Vehicles': 4,
#  'UFC': 105,
#  'puppet history': 16,
#  'Cody Garbrandt': 3,
#  'randomfrankp': 17,
#  'KPIX 5 News Evening': 3,
#  'snoop dogg': 34,
#  'Blizzard': 44,
#  'PORTUGAL': 2,
#  'barcelona': 81,
#  'dude perfect': 91,
#  'russian revolution': 15,
#  'crafts': 13,
#  'god awful country': 6,
#  'julien and jenna': 6,
#  'creative': 18,
#  'Ram': 6,
#  'nle choppa': 12,
#  'Reggaeton music': 16,
#  'TFLtruck': 10,
#  'Paris Hilton': 13,
#  'The Zaid Family': 6,
#  'Galaxy Tab S7+': 6,
#  'TFLoffroad': 6,
#  'Note 20 Ultra': 6,
#  'Pitch Perfect': 33,
#  'try channel': 12,
#  'Oliver Tree': 9,
#  'Kardashians': 45,
#  'pseu22072019tag': 6,
#  'Space': 46,
#  'full mount mma': 5,
#  'Golf': 59,
#  'whistlindiesel': 12,
#  'cricket': 22,
#  'Rooster Teeth': 51,
#  'josiah': 6,
#  'EUROPA LEAGUE': 3,
#  'dwyane wade': 7,
#  'BIGHIT': 45,
#  'entertainment': 143,
#  'Pokimane': 11,
#  'dixie damelio': 271,
#  'Freestyle': 5,
#  'Joe Rogan Experience': 17,
#  'Zias!': 6,
#  'M2': 25,
#  'wejdene': 13,
#  'swoozie': 16,
#  'Elections': 14,
#  '투모로우바이투게더': 29,
#  'explanation': 21,
#  'veritasium': 45,
#  'AOC': 6,
#  'psg': 38,
#  'Schaffrillas Productions': 10,
#  'alex meyers': 11,
#  'Awesomenesstv': 7,
#  'Maskey': 5,
#  'poisson fécond': 15,
#  'Creating The Ultimate Nut Butter': 5,
#  'espn': 148,
#  'The Howard Stern Show': 17,
#  'Flea': 10,
#  'polo g': 37,
#  'Ranton': 5,
#  'Luke Thomas': 5,
#  'too faced born this way': 5,
#  'sidhu moose wala new song': 7,
#  'call of duty cold war': 5,
#  'masai ujiri': 4,
#  'Symfuhny': 10,
#  'david dobrik': 56,
#  'Billie': 18,
#  'DNC': 10,
#  'Trailer': 84,
#  'b like that': 4,
#  'reubekah vidz': 5,
#  'ryan george': 26,
#  'swear word': 6,
#  'Underworld': 6,
#  'tiktok': 450,
#  'sleepy hallow': 10,
#  'avatar the last airbender': 20,
#  'Corn': 5,
#  'a24': 9,
#  '효린': 5,
#  'colleen ballinger': 21,
#  'try guys': 70,
#  'Los Angeles Times': 5,
#  'Dragon Ball Super Manga Chapter 63 Spoilers': 4,
#  'PSG LEIPZIG': 7,
#  'junky': 4,
#  'THIS AINT A HELLCAT ISSA DEMON MY CAR A PUSH START I BE LEAVING ALOT‼️': 4,
#  'ios 14': 119,
#  'Roman': 29,
#  'Need It': 6,
#  'envelope laser rectangle': 12,
#  'artisthbtl': 4,
#  'The Crown': 22,
#  'kung fu panda': 6,
#  'PS5': 58,
#  'ITZY': 44,
#  'lagonda taraf': 5,
#  'drew barrymore': 35,
#  'When the piano plays you': 5,
#  'Conan': 12,
#  'Headie One': 3,
#  'Squawk on the Street': 4,
#  'Desk Video': 5,
#  'Pharrell': 6,
#  'dallas mavericks': 25,
#  'sonic': 27,
#  'mug cake recipe': 4,
#  'Fredo Bang': 8,
#  'Noah Beck Awesomenesstv': 7,
#  'goat vs moose': 5,
#  'call of duty': 40,
#  'BTS': 216,
#  'adesanya': 22,
#  'top5': 8,
#  'how to': 308,
#  'madison beer': 38,
#  'Not Shy': 6,
#  '#brisxlife': 13,
#  'Deftones': 7,
#  'MissMulatto': 7,
#  'FivioForeign': 5,
#  'Maluma': 24,
#  'magia': 3,
#  'le pire et le meilleur': 4,
#  'thehacksmith': 51,
#  'JOJO SIWA': 6,
#  'the plan': 13,
#  'cimorelli': 14,
#  'jxdn': 17,
#  'SiriusXM': 26,
#  'gavin': 30,
#  'living big in a tiny house': 13,
#  'bts dynamite': 33,
#  'FO Squad Kpop': 8,
#  'mma': 133,
#  'wwe': 35,
#  'bts': 118,
#  'MUSICA': 3,
#  'Ryan': 3,
#  'snow tha product': 3,
#  'dnc': 3,
#  'los angeles clippers': 26,
#  'Conservative': 5,
#  'Surprising The Hype House With A Custom Bus': 7,
#  'addison rae': 75,
#  'Release the Snyder cut': 9,
#  'the batman': 39,
#  'suicide squad kill the justice league': 5,
#  'Wonder Woman 1984': 9,
#  '60 Minutes': 5,
#  'how to watch': 7,
#  'on fait': 5,
#  'KQ': 5,
#  'hyper rpg': 5,
#  'alexander povetkin': 9,
#  'Nike': 4,
#  'Luka Doncic': 17,
#  'ddg': 20,
#  'The Suicide Squad': 3,
#  'The Batman Trailer': 9,
#  'UCL': 23,
#  'new rockstars': 24,
#  'CBS 2 News Weekends': 4,
#  'when will we get the tart tycoon skin': 4,
#  'looper': 15,
#  'inside the nba': 4,
#  'sky sports boxing': 5,
#  'I had an accident': 4,
#  'cilvanis': 9,
#  'payton': 4,
#  'All Elite Wrestling': 16,
#  'Bret Maverick': 7,
#  'WALL·E': 4,
#  'news': 437,
#  'hurricane': 35,
#  'dillian whyte': 9,
#  'Ryging King': 3,
#  '쇼음악중심': 26,
#  "Zack Snyder's Justice League Trailer": 3,
#  'Ayzha Nyree': 3,
#  'icebox': 2,
#  'bts reaction': 24,
#  'nhl': 75,
#  'seth': 6,
#  'C-SPAN': 45,
#  'Beyoncé': 6,
#  'varinder brar': 5,
#  'luka doncic': 12,
#  'FaZe': 30,
#  'amr diab': 5,
#  'asmr': 59,
#  'World of Warcraft': 33,
#  'magic': 76,
#  'nba 2k21': 15,
#  'You Have Been Distracted': 4,
#  'enfermée pendant 25 ans': 4,
#  'Marcus Veltri': 9,
#  'BTS(방탄소년단)': 7,
#  'What Henry Stickmin Sounds Like sounds distracted - MIDI Art': 3,
#  'noah beck': 148,
#  'tom scott': 45,
#  'KARD': 18,
#  'gotham knights': 2,
#  'Millie Bobby Brown': 15,
#  "d'amelio": 177,
#  'domics': 17,
#  'sky sports': 41,
#  'Say Yes to the Dress': 17,
#  'vodk': 9,
#  'Daz': 5,
#  'hotboii': 10,
#  'NBA 2K20 2K NBA': 5,
#  'unspeakable': 10,
#  'borderlands 3': 5,
#  'Landon Clifford Camryn Clifford': 4,
#  'kurtis conner': 10,
#  'meat tornado': 5,
#  'Dyeing a wig for the FIRST TIME': 5,
#  'Vegas Golden Knights': 18,
#  'favorite stuff': 10,
#  'tlc': 51,
#  'barbie': 18,
#  'exercise': 23,
#  'lifestyle': 106,
#  'lucas studio': 9,
#  'jon prosser': 15,
#  'sony mistakes': 4,
#  'GCN Racing': 9,
#  'SATIRE': 16,
#  'iOS 14': 79,
#  'He shoved me into a fence': 4,
#  'Wish': 4,
#  'BET': 8,
#  'edwardian cape': 4,
#  'New Show': 1,
#  'rema': 3,
#  'clean bandit': 5,
#  'Ashe': 3,
#  'NPR': 22,
#  'NBA 2K21 DEMO': 3,
#  'pirlo meets juventus': 3,
#  'Local News': 3,
#  'repair': 13,
#  'hbo': 19,
#  'diy': 251,
#  'telefoot': 2,
#  'rapper': 58,
#  'carwow': 3,
#  'jimmy': 15,
#  'usa today': 9,
#  'rihanna': 10,
#  'a$ap rocky': 5,
#  'nintendo': 65,
#  'Hurricane Laura': 17,
#  'airline': 5,
#  'gigi': 12,
#  'PlayStation Plus': 4,
#  'News': 123,
#  'migos': 14,
#  '쇼챔피언': 10,
#  'legends of runeterra': 4,
#  'Guizzi': 8,
#  'kitten': 14,
#  'PWR': 11,
#  'iphone 12': 177,
#  'football daily': 4,
#  'ATP': 12,
#  'critical role': 10,
#  'sora': 11,
#  'cam and fam': 13,
#  'Riot Games': 47,
#  'thomas petrou': 47,
#  'nicki minaj': 16,
#  'hot ones': 52,
#  'Cordae': 6,
#  'calvin harris': 7,
#  'jeu mobile': 5,
#  'local': 50,
#  'ET Broadcast': 5,
#  'SCVWordPress': 11,
#  'Destiny': 36,
#  'Jacob': 5,
#  'Tenet': 12,
#  'Little mix': 10,
#  'The New Mutants': 5,
#  'K/DA': 4,
#  'wb games': 4,
#  'Andrew piluk blackpink': 4,
#  'Jason Derulo': 6,
#  "moi c'est noa": 4,
#  'nikkietutorials': 61,
#  'japan': 36,
#  'mass appeal': 12,
#  'The Bella Twins': 3,
#  'girl in red lyrics': 3,
#  'KCAL 9 News Evening': 6,
#  'Chadwick Boseman': 44,
#  'Matt Stonie': 43,
#  'tyrone magnus': 6,
#  'CNET': 11,
#  'king von': 22,
#  'The Sports World REACTS to the Passing of Chadwick Boseman...RIP! #WakandaForever': 6,
#  'paris': 57,
#  'thr': 10,
#  'Katy': 12,
#  'blackpink': 58,
#  'monster hunter': 17,
#  'Hackers in Video Games': 5,
#  'nathan dawe': 4,
#  'selena gomez': 73,
#  'Zoom': 13,
#  'its alex clark': 4,
#  'Boxing': 34,
#  'the nbhd': 3,
#  'Creepypasta': 3,
#  'rick astley': 4,
#  'motorcycle': 7,
#  'the office': 16,
#  'behind the moment': 3,
#  "simon's cat": 12,
#  'Star Wars': 31,
#  'homeless sweeps denver': 3,
#  'Stray Kids': 36,
#  'sidhu moosewala': 19,
#  'karan aujla': 13,
#  'Weekend TODAY': 13,
#  'when you finally write a hit song but your cat is dead': 12,
#  'VRE': 22,
#  'dhar mann': 11,
#  'intello': 7,
#  'Top Stories': 41,
#  'tour de france': 12,
#  'slomo': 26,
#  'Tennis': 28,
#  'Joueur du grenier': 12,
#  'hello newmans season 3': 5,
#  'twins': 28,
#  'piemations': 5,
#  'blue frog mumbai': 4,
#  'Spurs': 25,
#  '2020': 664,
#  'spiritualism': 4,
#  'Arsenal': 43,
#  'Kevin Smith': 4,
#  'Big': 32,
#  'catplant': 3,
#  'MTV': 26,
#  'tagsbullet': 3,
#  'Zao MKE Church': 3,
#  'fr': 49,
#  'The Sims 4': 14,
#  'black': 10,
#  'Oecophylla weaver ants': 7,
#  'marvel': 82,
#  'yestheory': 35,
#  'Linus': 27,
#  'sssniperwolf': 28,
#  'Tour de France': 19,
#  'jaclynhill1': 11,
#  'TimTom': 6,
#  'highlights': 351,
#  'kpop': 149,
#  'matwaliye satinder sartaj': 3,
#  '하이라인': 10,
#  'Peter McKinnon': 16,
#  'online fashion': 6,
#  'fear nothing mikey williams episode 6': 6,
#  'Heath Hussar': 11,
#  'what if': 10,
#  'Chloe': 12,
#  'Bill & Ted Face the Music': 4,
#  'dabl': 5,
#  'erwan': 4,
#  'maho': 8,
#  'Chelsea F.C. (Football Team)': 26,
#  'the reel rejects': 4,
#  'or noir': 3,
#  'FD': 3,
#  'drew gooden': 37,
#  'mystery and makeup': 10,
#  'jojo': 23,
#  'Michael B Jordan': 5,
#  'punjabi': 42,
#  'TheStradman': 11,
#  'chic fil a': 6,
#  'Verzuz': 6,
#  'box art template': 6,
#  'Zaid': 6,
#  'quetzocoatlus': 6,
#  'AJR': 6,
#  'renovation': 12,
#  'hannah meloche hannah teen school college': 6,
#  'labor vlog': 10,
#  'us open': 36,
#  'alvin zhou': 12,
#  'squeezie thread horreur': 13,
#  'The Prince Family': 5,
#  'choreography': 44,
#  'Lenarr': 15,
#  'Luke Combs': 5,
#  'theamaazing': 5,
#  'lil baby low down': 4,
#  'nvidia': 29,
#  'NVIDIA': 14,
#  'singga': 6,
#  'gamersnexus': 7,
#  'clash of clans': 28,
#  'Miley Cyrus': 69,
#  'rtx 3090': 24,
#  'Ozuna Odisea': 10,
#  'apple September event': 5,
#  'black clover': 5,
#  '#IONIQ': 5,
#  'protests': 18,
#  'spencer f2': 5,
#  'A.C.E': 5,
#  'ratatouille': 23,
#  'before they were famous': 4,
#  'bright side': 10,
#  'nota bene': 9,
#  'gabbie hanna': 19,
#  'pat mcafee': 10,
#  'Loren': 5,
#  'first take': 78,
#  'ingredient swap': 5,
#  'leandre sanders game of skate': 5,
#  'Byzantine Empire': 5,
#  'jurassic world': 10,
#  'sidhu moose wala': 16,
#  'David Blaine': 22,
#  'markiplier': 63,
#  'laser': 13,
#  'airrack': 11,
#  'The Game': 6,
#  'Bring me the horizon': 7,
#  'how to post on r videos': 6,
#  'pregnancy announcement': 43,
#  'FINNEAS': 4,
#  'bryson tiller inhale': 9,
#  'my dog has a puppy sleepover': 29,
#  'alissa ashley': 6,
#  'Liza': 5,
#  'wagyu': 11,
#  'mre': 6,
#  'I HATE EVERYTHING': 6,
#  'shoes': 5,
#  'gims': 27,
#  'abc': 49,
#  'nessa barrett': 5,
#  'alan watts': 4,
#  'itsmyrayeraye': 4,
#  'paul davids': 4,
#  'NASA': 18,
#  'Lakeland PBS': 4,
#  'Father Of Ashad': 9,
#  'sza': 8,
#  'nba 2k21 story': 6,
#  'James Bond': 10,
#  'grammy awards': 7,
#  'Chloe x Halle new video': 7,
#  'jackson wang': 6,
#  'chuck e cheese': 7,
#  'Isaiah Shepard': 5,
#  'ChrisFix': 14,
#  'laser cutter': 5,
#  'Mulan': 18,
#  "Absorber - Trollin' (Official Music Video)": 3,
#  "4 Signs That You're Boujee": 5,
#  'Lele Pons': 5,
#  'australian': 5,
#  'bitwit': 18,
#  'anthony padilla': 20,
#  'billboard': 16,
#  'lil durk': 31,
#  'debunking': 7,
#  'Among Us in a Nutshell': 6,
#  'star wars': 71,
#  'Note 20 Ultra review': 6,
#  'mike horn': 25,
#  'Sech': 16,
#  '6ix9ine': 44,
#  'Officers kill man linked to fatal downtown Portland shooting': 4,
#  'Jeep': 4,
#  'Matthew Doyon': 11,
#  'I tried acrylic pour art for the first time': 8,
#  'born to shine diljit dosanjh': 8,
#  'vat19': 36,
#  'Horse racing': 6,
#  'Ryan Garcia': 15,
#  'a special announcement': 6,
#  'when somebody is too good at bargaining': 6,
#  'Randomonium': 6,
#  'football': 368,
#  'ssj carter': 6,
#  'Ukay ukay': 5,
#  'Crunchyroll': 10,
#  'DFB': 16,
#  'buying skulls': 5,
#  'Tasty': 29,
#  'physics girl': 4,
#  'Mountain biking': 4,
#  'lankybox': 6,
#  'Lost LeBlanc': 4,
#  'england u21 vs kosovo u21': 3,
#  'ken block': 3,
#  'Overwatch': 3,
#  'Jelly Roll': 13,
#  'Reactions': 23,
#  'Ostendo': 7,
#  'Tryguys': 6,
#  'LE': 27,
#  'vlog': 560,
#  'kaur b': 7,
#  'Novak Djokovic': 25,
#  'Tarrus': 7,
#  'Squirmy and Grubs': 6,
#  'arirang': 5,
#  'mohamed ramadan': 7,
#  'trying to conceive': 5,
#  '6ix9ine - LOCKED UP PT 2 (Feat. Akon) [Official Lyric Video]': 6,
#  'lolywood': 20,
#  'DESI PERKINS': 21,
#  'Patrick starrr': 6,
#  'jujufitcat': 16,
#  'swim lessons': 5,
#  'england vs iceland': 5,
#  'youtwotv': 25,
#  'Rare beauty': 5,
#  'haulover boats': 5,
#  'heaver rainstorm flooded our basement': 6,
#  'Lakers': 84,
#  'joyforsyth': 5,
#  'hihacks': 12,
#  'home yoga': 13,
#  'scp animated': 12,
#  'Team Crouton': 11,
#  'jahan et romane': 12,
#  'bardcore': 4,
#  'earthlinged': 4,
#  'pop up cabin': 4,
#  'Machine Gun Kelly': 52,
#  'lady gaga': 10,
#  'Lil Loaded': 8,
#  'brawl stars': 23,
#  'Kyle Exum': 23,
#  'graystillplays': 6,
#  'Nyma Tang': 7,
#  'Manny Khosbin': 6,
#  'Kpop': 90,
#  'Chunkz Entertainment': 11,
#  'Soccer aid 2020': 5,
#  'FC Barcelona': 24,
#  'Xbox': 97,
#  'Wranglerstar': 5,
#  'bay ridge shooting': 5,
#  'hot sauce': 36,
#  'nadeshot': 19,
#  'Local news': 10,
#  'Tottenham Hotspur': 23,
#  'trump boat parade': 5,
#  'skate': 21,
#  'Kentucky derby': 4,
#  'cypher': 15,
#  'Kylie Cosmetics': 14,
#  'Amelie zilber': 18,
#  'TOBJIZZLE': 6,
#  'mcdonalds': 42,
#  'android 11': 6,
#  'trick shots': 85,
#  'apple September event 2020': 6,
#  'Tailosive': 6,
#  'comethazine': 10,
#  'how classroom discussions went in middle school': 6,
#  'reviewtechusa': 5,
#  'survivre': 11,
#  'xbox series x': 97,
#  'xbox series s': 43,
#  'MAMAMOO': 43,
#  'xbox': 101,
#  'The Voice': 50,
#  'the weeknd': 35,
#  'hyper': 5,
#  'physics': 59,
#  'McLaren': 22,
#  'album': 32,
#  'midnight sky live': 10,
#  'Arsenal F.C.': 5,
#  'mansion': 4,
#  'chef vitale': 4,
#  'Ryland Adams': 6,
#  'wildfire': 13,
#  'Thedooo': 5,
#  'TV Series': 40,
#  'medical advice': 5,
#  'Gorillaz': 13,
#  'the breakfast club': 8,
#  'star wars expalined': 5,
#  'basketball': 218,
#  'tlc australia': 5,
#  'wallows': 5,
#  'black lives matter': 18,
#  'Nolifeshaq reactions': 4,
#  'challenge': 188,
#  'jake paul': 95,
#  'squeezie omegle': 5,
#  'Blondedy Ferdinand': 6,
#  'kfc': 8,
#  'davido': 8,
#  'marshmello': 12,
#  '30 series gpu': 9,
#  'Trippie Redd': 9,
#  'Tekashi 6ix9ine': 14,
#  '#lepadre #regardemoi #ferregola #africaurbain #nouveaute #rdc #congo #graal': 4,
#  'kbs': 14,
#  'met': 14,
#  'afunkydiabetic': 5,
#  'kevin durant': 29,
#  'Soolking': 12,
#  'formula 1': 15,
#  'batman': 44,
#  'survie': 25,
#  'Minecraft': 17,
#  'ruel': 4,
#  'sushi': 23,
#  'KOMO': 4,
#  'yacetom': 9,
#  'dan plan': 9,
#  'squishy makeover': 6,
#  'Verbal Ase': 5,
#  'how ridiculous': 21,
#  'storage wars': 5,
#  'Poison Damage in RPGs': 5,
#  'Son Lloris Agument': 5,
#  'dancehall': 16,
#  'wflatampa': 4,
#  'Dogs': 10,
#  'Joli bébé': 4,
#  'ankylosing spondylitis': 4,
#  'pirate shirt': 4,
#  'Tampa Bay Buccaneers': 7,
#  'Nissan': 9,
#  'Galaxy buds live': 4,
#  'luke combs': 16,
#  'Top Gear': 18,
#  's1mba': 3,
#  'the voice': 42,
#  'RC LENS PARIS SG': 3,
#  'CNBC': 29,
#  'FNAF': 7,
#  'Liverpool FC': 23,
#  'PlayStation': 67,
#  'my dog is a derp': 12,
#  '3d printer': 15,
#  'trixie mattel': 34,
#  'triller': 9,
#  'DW News': 11,
#  'fall outfit ideas': 9,
#  'my mechanics': 4,
#  'doc seven': 12,
#  'wish': 4,
#  'microsoft': 59,
#  'Kevin James': 8,
#  'Marshmello': 3,
#  'somi': 3,
#  'food review': 33,
#  'daddy yankee en vivo': 3,
#  'beIN SPORTS': 64,
#  'beINSPORTS': 6,
#  "d'angelo wallace": 7,
#  'PARIS SG OM': 6,
#  'JYP': 73,
#  'CL': 14,
#  'Spurs 0-1 Everton highlights': 5,
#  'ben azelart': 19,
#  'brian': 10,
#  'britneyandbaby': 4,
#  'lexi Hensler': 6,
#  'latoyaforever': 5,
#  'manchester united': 47,
#  'Among Us': 49,
#  'we broke up': 18,
#  'why did we break up': 4,
#  'Liam Payne': 7,
#  "le monde a l'envers": 9,
#  'LC500': 5,
#  'computer': 39,
#  'april wilkerson': 8,
#  'Oregon wildfire': 4,
#  'amazon': 64,
#  'tik tok': 424,
#  'russian skating': 3,
#  "Conan O'Brien": 9,
#  'ontario covid': 6,
#  'New York State': 5,
#  'liziqi': 19,
#  'Venus': 6,
#  'N64': 12,
#  'dungeons and dragon': 6,
#  'yt:quality=high': 11,
#  'pontiac': 6,
#  'coyote peterson': 27,
#  'squeezie subreddit': 12,
#  'venus': 6,
#  ...}

# %%
import operator
sorted(tag_count.items(), key=operator.itemgetter(1),reverse=True)
# Out:
# [('funny', 1026),
#  ('comedy', 894),
#  ('2020', 664),
#  ('vlog', 560),
#  ('animation', 466),
#  ('tiktok', 450),
#  ('news', 437),
#  ('tik tok', 424),
#  ('music', 387),
#  ('football', 368),
#  ('among us', 362),
#  ('highlights', 351),
#  ('review', 326),
#  ('NBA', 320),
#  ('reaction', 313),
#  ('how to', 308),
#  ('music video', 299),
#  ('Football', 294),
#  ('soccer', 289),
#  ('video', 284),
#  ('family', 274),
#  ('dixie damelio', 271),
#  ('rap', 264),
#  ('charli damelio', 263),
#  ('new', 258),
#  ('interview', 257),
#  ('diy', 251),
#  ('Highlights', 251),
#  ('fun', 242),
#  ('nba', 237),
#  ('james charles', 232),
#  ('Basketball', 232),
#  ('gaming', 230),
#  ('science', 227),
#  ('ufc', 225),
#  ('Rap', 222),
#  ("dixie d'amelio", 222),
#  ('hip hop', 222),
#  ("charli d'amelio", 221),
#  ('basketball', 218),
#  ('education', 218),
#  ('sports', 217),
#  ('BTS', 216),
#  ('food', 210),
#  ('charli', 208),
#  ('dixie', 208),
#  ('apple', 196),
#  ('game', 195),
#  ('cartoon', 194),
#  ('sketch', 190),
#  ('challenge', 188),
#  ('ps5', 187),
#  ('tech', 187),
#  ('Pop', 187),
#  ('trailer', 185),
#  ('unboxing', 185),
#  ('NBA Playoffs', 185),
#  ('family friendly', 182),
#  ('damelio', 179),
#  ('funny videos', 179),
#  ('vs', 178),
#  ("d'amelio", 177),
#  ('iphone 12', 177),
#  ('live', 176),
#  ('G League', 175),
#  ('buzzfeed', 174),
#  ('parody', 173),
#  ('humour', 172),
#  ('technology', 168),
#  ('Hip Hop', 166),
#  ('premier league', 165),
#  ('youtube', 165),
#  ('beauty', 164),
#  ('cute', 164),
#  ('Music', 163),
#  ('humor', 162),
#  ('goals', 157),
#  ('Funny', 156),
#  ("marc d'amelio", 153),
#  ("heidi d'amelio", 153),
#  ('Disney', 152),
#  ('kpop', 149),
#  ('react', 149),
#  ('espn', 148),
#  ('noah beck', 148),
#  ('video game', 147),
#  ('meme', 147),
#  ('Highlight', 145),
#  ('Entertainment', 143),
#  ('entertainment', 143),
#  ('iphone 12 pro', 143),
#  ('playstation 5', 142),
#  ('sidemen', 139),
#  ('makeup', 139),
#  ('Records', 139),
#  ('exclusive', 137),
#  ('gameplay', 136),
#  ('comedian', 136),
#  ('Donald Trump', 135),
#  ('the', 134),
#  ('cooking', 134),
#  ('mma', 133),
#  ('experiment', 133),
#  ('방탄소년단', 132),
#  ('halloween', 131),
#  ('official', 130),
#  ('NBA Restart', 130),
#  ('Family', 127),
#  ('iphone 12 pro max', 126),
#  ('buzzfeedvideo', 126),
#  ('Sports', 124),
#  ('sport', 124),
#  ('fight', 124),
#  ('fortnite', 123),
#  ('News', 123),
#  ('among us animation', 123),
#  ('sister', 123),
#  ('tutorial', 122),
#  ('matpat', 122),
#  ('DIY', 120),
#  ('messi', 120),
#  ('ios 14', 119),
#  ('fail', 119),
#  ('bts', 118),
#  ('iPhone 12', 118),
#  ('hacks', 118),
#  ('reviews', 118),
#  ('test', 118),
#  ('vlogs', 117),
#  ('K-pop', 117),
#  ('goal', 117),
#  ('boyfriend', 117),
#  ('james', 115),
#  ('song', 115),
#  ('Jump Shot', 115),
#  ('hollywood', 115),
#  ('fashion', 114),
#  ('official music video', 114),
#  ('commentary', 114),
#  ('Comedy', 113),
#  ('easy makeup', 113),
#  ('Video)', 113),
#  ('Soccer', 112),
#  ('politics', 112),
#  ('celebrity', 111),
#  ('Los Angeles Lakers', 111),
#  ('play', 111),
#  ('hype house', 111),
#  ('clip', 110),
#  ('chef', 110),
#  ('playstation', 108),
#  ('블랙핑크', 108),
#  ('와이지', 107),
#  ('clean', 107),
#  ('Teaser', 107),
#  ('lifestyle', 106),
#  ('drama', 106),
#  ('tik tok makeup', 106),
#  ('UFC', 105),
#  ('Sport', 105),
#  ('animated', 105),
#  ('dude', 104),
#  ('boxing', 104),
#  ('tik tok hacks', 104),
#  ('dp', 104),
#  ('lol', 103),
#  ('celebrities', 103),
#  ('history', 103),
#  ('morphe', 103),
#  ('Music Video', 102),
#  ('show', 102),
#  ('tutorials', 102),
#  ('minecraft', 101),
#  ('xbox', 101),
#  ('life', 101),
#  ('highlight', 100),
#  ('laugh', 100),
#  ('do it yourself', 99),
#  ('impostor', 99),
#  ('지수', 99),
#  ('제니', 99),
#  ('로제', 99),
#  ('리사', 99),
#  ('battle', 99),
#  ('YG Entertainment', 98),
#  ('YG', 98),
#  ('Xbox One', 98),
#  ('dog', 98),
#  ('best', 98),
#  ('hilarious', 98),
#  ('try', 98),
#  ('trending', 98),
#  ('yt:cc=on', 98),
#  ('Xbox', 97),
#  ('xbox series x', 97),
#  ('video games', 97),
#  ('trump', 97),
#  ('coronavirus', 97),
#  ('chase hudson', 96),
#  ('late night', 96),
#  ('how-to', 96),
#  ('2019-20 Season', 96),
#  ('NBA Season', 96),
#  ('love', 96),
#  ('2019-20', 96),
#  ('Whole New Game', 96),
#  ('Full Game Highlights', 96),
#  ('Full Game Recap', 96),
#  ('ksi', 95),
#  ('jake paul', 95),
#  ('LeBron James', 94),
#  ('Food', 94),
#  ('2020 election', 94),
#  ('reacting', 94),
#  ('vlogger', 94),
#  ('Action', 94),
#  ('recipe', 94),
#  ('smartphone', 93),
#  ('iphone', 92),
#  ('imposter', 92),
#  ('gadgets', 92),
#  ('podcast', 92),
#  ('Steal', 92),
#  ('Rebound', 92),
#  ('Assist', 92),
#  ('Pass', 92),
#  ('Playoffs', 92),
#  ('dude perfect', 91),
#  ('champions league', 91),
#  ('Kpop', 90),
#  ('BLACKPINK', 90),
#  ('Joe Biden', 90),
#  ('games', 90),
#  ('iphone 12 mini', 90),
#  ('bowling', 90),
#  ('BANGTAN', 89),
#  ('beauty tips', 89),
#  ('F1', 88),
#  ('Formula 1', 88),
#  ('makeup artist', 88),
#  ('sway house', 88),
#  ('Premier League', 88),
#  ('james charles x morphe', 88),
#  ('dazn', 87),
#  ('Kylie Jenner', 87),
#  ('logan paul', 87),
#  ('dogs', 87),
#  ('joe biden', 87),
#  ('marc', 87),
#  ('heidi', 87),
#  ('NFL', 86),
#  ('prank', 86),
#  ('netflix', 86),
#  ('PC', 86),
#  ('fox', 85),
#  ('trick shots', 85),
#  ('lebron james', 85),
#  ('ufc 254', 85),
#  ('apple iphone 12', 85),
#  ('canada', 85),
#  ('funny video', 85),
#  ('film theory', 85),
#  ('game theory', 85),
#  ('Trailer', 84),
#  ('Lakers', 84),
#  ('donald trump', 84),
#  ('talk show', 84),
#  ('vine', 84),
#  ('simon', 83),
#  ('miniminter', 83),
#  ('ping pong', 83),
#  ('makeup tutorial', 83),
#  ('marvel', 82),
#  ('TWICE', 82),
#  ('Video', 82),
#  ('apple iphone', 82),
#  ('action', 82),
#  ('mystery', 82),
#  ('sisters apparel', 82),
#  ('tik tok beauty hacks', 82),
#  ('movie', 81),
#  ('Manchester United', 81),
#  ('barcelona', 81),
#  ('Miami Heat', 81),
#  ('viral', 81),
#  ('mua', 81),
#  ('film theorists', 81),
#  ('game theorists', 81),
#  ('surprise', 80),
#  ('house tour', 80),
#  ('lil huddy', 80),
#  ('Columbia', 80),
#  ('lakers', 80),
#  ('khabib nurmagomedov', 80),
#  ('story', 80),
#  ('among us funny', 80),
#  ('relationship', 80),
#  ('stream', 80),
#  ('iOS 14', 79),
#  ('ariana grande', 79),
#  ('playoffs', 79),
#  ('among us memes', 79),
#  ('epl', 79),
#  ('edition', 79),
#  ('first take', 78),
#  ('Formula One', 78),
#  ('biden', 78),
#  ('skit', 78),
#  ('bottle flip', 78),
#  ('RM', 78),
#  ('satire', 78),
#  ('Netflix', 77),
#  ('trick shot', 77),
#  ('ufc news', 77),
#  ('covergirl', 77),
#  ('behind the scenes', 77),
#  ('coverboy', 77),
#  ('Anthony Davis', 77),
#  ('magic', 76),
#  ('anime', 76),
#  ('PS4', 76),
#  ('TikTok', 76),
#  ('breaking news', 76),
#  ('breakfast', 76),
#  ('jeffree star', 75),
#  ('addison rae', 75),
#  ('nhl', 75),
#  ('ios 14 features', 75),
#  ('BuzzFeed', 75),
#  ('snl', 75),
#  ('keith', 75),
#  ('france', 75),
#  ('taste test', 75),
#  ('reveal', 75),
#  ('latest punjabi songs 2020', 75),
#  ('케이팝', 75),
#  ('pregnancy', 74),
#  ('lyrics', 74),
#  ('TV', 74),
#  ('recap', 74),
#  ('kids', 74),
#  ('cook', 74),
#  ('Movie', 74),
#  ("dixie d'amelio be happy", 74),
#  ('selena gomez', 73),
#  ('JYP', 73),
#  ('fast food', 73),
#  ('dude perfect stereotypes', 73),
#  ('charlie', 73),
#  ("charlie d'amelio", 73),
#  ('dude perfect water bottle flip', 73),
#  ('water bottle flip', 73),
#  ('real', 73),
#  ('dude perfect bottle flip', 73),
#  ('dude perfect basketball', 73),
#  ('dude perfect world record', 73),
#  ('nerf', 73),
#  ('charlie damelio', 73),
#  ('bubble wrap', 73),
#  ('spinner', 73),
#  ('spinners', 73),
#  ('fidget spinners', 73),
#  ('hockey', 72),
#  ('Apple', 72),
#  ('world', 72),
#  ('parodie', 72),
#  ('Atlantic Records', 72),
#  ('among us imposter', 72),
#  ('kitchen', 72),
#  ('learn', 72),
#  ('star wars', 71),
#  ('israel adesanya', 71),
#  ('트와이스', 71),
#  ('among us gameplay', 71),
#  ('be happy', 71),
#  ('idol', 71),
#  ('dixie damelio be happy', 71),
#  ('try guys', 70),
#  ('League of Legends', 70),
#  ('ned', 70),
#  ('pc', 70),
#  ('ariel', 70),
#  ('new york', 70),
#  ('zach', 70),
#  ('eugene', 70),
#  ('la liga', 70),
#  ('habersberger', 70),
#  ('Hip', 70),
#  ('fulmer', 70),
#  ('versus', 70),
#  ('kornfeld', 70),
#  ('yang', 70),
#  ('ned & ariel', 70),
#  ('tryceratops', 70),
#  ('Miley Cyrus', 69),
#  ('History', 69),
#  ('couple', 69),
#  ('ios 14 widgets', 69),
#  ('musique', 69),
#  ('American Football', 69),
#  ('Futbol', 69),
#  ('Travel', 69),
#  ('storytime', 69),
#  ('Jisoo', 69),
#  ('lyric video', 69),
#  ('Jennie', 69),
#  ('guru', 69),
#  ('Battle Royale', 69),
#  ('Rosé', 69),
#  ('monster', 69),
#  ('블핑', 69),
#  ('Lisa', 69),
#  ('Grand Prix', 69),
#  ('블링크', 69),
#  ('NBA Bubble', 69),
#  ('binging with babish', 68),
#  ('stephen a smith', 68),
#  ('fox sports', 68),
#  ('빅히트', 68),
#  ('fs1', 68),
#  ('fox sports 1', 68),
#  ('Celebrities', 68),
#  ('nba espn', 68),
#  ('watch', 68),
#  ('PlayStation', 67),
#  ('MMA', 67),
#  ('khabib', 67),
#  ('Man Utd', 67),
#  ('time', 67),
#  ('baby', 67),
#  ('Lifestyle', 67),
#  ('among us funny moments', 67),
#  ('ps4', 67),
#  ('AD', 67),
#  ('slow', 66),
#  ('motion', 66),
#  ('girlfriend', 66),
#  ('GP', 66),
#  ('therapy', 66),
#  ('Electronic Arts', 66),
#  ('full highlights', 66),
#  ('noah and dixie', 66),
#  ('nintendo', 65),
#  ('pregnant', 65),
#  ('gamer', 65),
#  ('television', 65),
#  ('challenges', 65),
#  ('4K', 65),
#  ('beIN SPORTS', 64),
#  ('amazon', 64),
#  ('Cristiano Ronaldo', 64),
#  ('Ronaldo', 64),
#  ('Fortnite', 64),
#  ('beIN SPORTS USA', 64),
#  ('stephen a', 64),
#  ('league of legends', 64),
#  ('official video', 64),
#  ('CR7', 64),
#  ('food porn', 64),
#  ('pop music', 64),
#  ('baking', 64),
#  ('Apex Legends', 63),
#  ('markiplier', 63),
#  ('Gaming', 63),
#  ('Man United', 63),
#  ('among us in real life', 63),
#  ('United', 63),
#  ('random', 63),
#  ('league', 63),
#  ('animatic', 63),
#  ('series', 63),
#  ('influencer', 63),
#  ('larray', 63),
#  ('ᗷᕼᑌᗴᔕᒍYᗴᔕ', 63),
#  ('beauty hacks', 63),
#  ('iPhone 12 Pro', 62),
#  ('us', 62),
#  ('LA Lakers', 62),
#  ('fighting', 62),
#  ('Physics', 62),
#  ('sony', 62),
#  ('punjabi songs', 62),
#  ('cycling', 62),
#  ('NBA Finals', 62),
#  ('nikkietutorials', 61),
#  ('Celebrity', 61),
#  ('tips', 61),
#  ('quarantine', 61),
#  ('us news', 61),
#  ('Film', 61),
#  ('Alternative', 61),
#  ('아이돌', 61),
#  ('unbox therapy', 60),
#  ('saturday night live', 60),
#  ('lebron', 60),
#  ('rpg', 60),
#  ('knockout', 60),
#  ('friends', 60),
#  ('Hop', 60),
#  ('Auto Racing', 60),
#  ('cringe', 60),
#  ('jhope', 60),
#  ('Motor Racing', 60),
#  ('BLINK', 60),
#  ('Cardi B', 59),
#  ('art', 59),
#  ('Golf', 59),
#  ('asmr', 59),
#  ('physics', 59),
#  ('microsoft', 59),
#  ('Juventus', 59),
#  ('Napoli', 59),
#  ('Serie A', 59),
#  ('Inter Milan', 59),
#  ('Eddie Van Halen', 59),
#  ('AC Milan', 59),
#  ('ufc highlights', 59),
#  ('Roma', 59),
#  ('iphone 12 review', 59),
#  ('Dybala', 59),
#  ('Vlog', 59),
#  ('(Official', 59),
#  ('adventure', 59),
#  ('tricks', 59),
#  ('cars', 59),
#  ('first take today', 59),
#  ('espn nba', 59),
#  ('calcio', 59),
#  ('lukaku', 59),
#  ('partita', 59),
#  ('makeup 2020', 59),
#  ('migliori gol', 59),
#  ('migliori in campo', 59),
#  ('migliori al mondo', 59),
#  ('gol del mese', 59),
#  ('federcalcio', 59),
#  ('Italia', 59),
#  ('JYP Entertainment', 58),
#  ('The United Stand', 58),
#  ('PS5', 58),
#  ('rapper', 58),
#  ('blackpink', 58),
#  ('KPOP', 58),
#  ('ultimate', 58),
#  ('United Stand', 58),
#  ('COVID-19', 58),
#  ('R&B', 58),
#  ('tour', 58),
#  ('crazy', 58),
#  ('Nintendo Switch', 58),
#  ('drake', 58),
#  ('championship', 58),
#  ('android', 58),
#  ('Denver Nuggets', 58),
#  ('champion', 58),
#  ('youtuber', 58),
#  ('behind', 58),
#  ('SUGA', 58),
#  ('host', 58),
#  ('building', 58),
#  ('jokes', 58),
#  ('makeup routines', 58),
#  ('2hype', 57),
#  ('Drake', 57),
#  ('paris', 57),
#  ('latest punjabi song 2020', 57),
#  ('MGK', 57),
#  ('PlayStation 4', 57),
#  ('vlogging', 57),
#  ('mukbang', 57),
#  ('nba playoffs', 57),
#  ('competition', 57),
#  ('Family Friendly', 57),
#  ('Kawhi Leonard', 57),
#  ('Voice', 57),
#  ('noah', 57),
#  ('david dobrik', 56),
#  ('xxl freshmen', 56),
#  ('NBC', 56),
#  ('live stream', 56),
#  ('buzzfeed video', 56),
#  ('Official Music Video', 56),
#  ('hip-hop', 56),
#  ('actor', 56),
#  ('latest punjabi songs', 56),
#  ('ESPN', 56),
#  ('Worth It', 56),
#  ('BuzzFeed Worth It', 56),
#  ('24h', 56),
#  ('BuzzFeed Steven', 56),
#  ('BuzzFeed Adam', 56),
#  ('BuzzFeed Andrew', 56),
#  ('Steven Lim', 56),
#  ('Math', 56),
#  ('Adam Bianchi', 56),
#  ('댄스', 56),
#  ('Cameraguy', 56),
#  ('me', 56),
#  ('andrew ilnyckyi', 56),
#  ('Cheap vs. expensive', 56),
#  ('Experience', 56),
#  ('michou', 55),
#  ('full match', 55),
#  ('Justin Bieber', 55),
#  ('White House', 55),
#  ('skills', 55),
#  ('new punjabi song 2020', 55),
#  ('among us irl', 55),
#  ('dixie and noah', 55),
#  ('Lewis Hamilton', 55),
#  ('Lazio', 55),
#  ('smosh', 54),
#  ('election', 54),
#  ('justin gaethje', 54),
#  ('Charlotte', 54),
#  ('travel', 54),
#  ('smosh games', 54),
#  ('nature', 54),
#  ('bros', 54),
#  ('fitness', 54),
#  ('all goals', 54),
#  ('atlantic records', 54),
#  ('los angeles lakers', 54),
#  ('Korea', 54),
#  ('LA', 54),
#  ('unbox', 54),
#  ('holiday', 54),
#  ('Apex Legends game', 54),
#  ('first take espn', 54),
#  ('Respawn Apex Legends', 54),
#  ('Apex Games', 54),
#  ('mom', 54),
#  ('Respawn Entertainment', 54),
#  ('dad', 54),
#  ('DaBaby', 53),
#  ('Megan Thee Stallion', 53),
#  ('cardi b', 53),
#  ('house', 53),
#  ('animations', 53),
#  ('Games', 53),
#  ('rock', 53),
#  ('ps5 gameplay', 53),
#  ('instagram', 53),
#  ('maverick', 53),
#  ('Club', 53),
#  ('방탄', 53),
#  ('Clippers', 53),
#  ('Viral', 53),
#  ('LBJ', 53),
#  ('espn mma', 53),
#  ('Jimmy Butler', 53),
#  ('M/V', 53),
#  ('hot ones', 52),
#  ('Machine Gun Kelly', 52),
#  ('comics', 52),
#  ('apple iphone 12 pro', 52),
#  ('car', 52),
#  ('Los Angeles', 52),
#  ('birthday', 52),
#  ('home', 52),
#  ('usa', 52),
#  ('Mystery', 52),
#  ('marc damelio', 52),
#  ('sisters', 52),
#  ('Tik Tok', 52),
#  ('world news', 52),
#  ('outdoors', 52),
#  ('heidi damelio', 52),
#  ('guest', 52),
#  ('among us hacks', 52),
#  ('the damelio family', 52),
#  ("the d'amelio family", 52),
#  ('Lil', 51),
#  ('nails', 51),
#  ('Rooster Teeth', 51),
#  ('thehacksmith', 51),
#  ('tlc', 51),
#  ('covid-19', 51),
#  ('Canada', 51),
#  ('unboxtherapy', 51),
#  ('nail art', 51),
#  ('RT', 51),
#  ('#espn', 51),
#  ('weather', 51),
#  ('Kim Kardashian', 51),
#  ('ufc 253', 51),
#  ('animals', 51),
#  ('nail tutorial', 51),
#  ('nba on espn', 51),
#  ('cat', 51),
#  ('offense', 51),
#  ('movies', 51),
#  ('beauty tutorial', 51),
#  ('new music', 51),
#  ('ko', 51),
#  ('dance', 51),
#  ('defense', 51),
#  ('Island', 51),
#  ('funny animation', 51),
#  ('doja cat', 51),
#  ('k-pop', 51),
#  ('diy nails', 51),
#  ('eating', 51),
#  ('lips', 51),
#  ('HD', 51),
#  ('diy nail art', 51),
#  ('Hip-Hop', 51),
#  ('simply nailogical', 51),
#  ('cristine', 51),
#  ('vote', 51),
#  ('Kobe Bryant', 51),
#  ('plays', 51),
#  ('season', 51),
#  ('touchdown', 51),
#  ('td', 51),
#  ('game highlights', 51),
#  ('best plays', 51),
#  ('top plays', 51),
#  ('xxl freshman', 50),
#  ('mcfly', 50),
#  ('CBS', 50),
#  ('The', 50),
#  ('local', 50),
#  ('The Voice', 50),
#  ('iphone 12 unboxing', 50),
#  ('smosh pit', 50),
#  ('carlito', 50),
#  ('Riot', 50),
#  ('bass', 50),
#  ('tools', 50),
#  ('français', 50),
#  ('reacts', 50),
#  ('ronaldo', 50),
#  ('Kanye West', 50),
#  ('comeback', 50),
#  ('dessert', 50),
#  ('Kevin', 50),
#  ('kylie jenner', 49),
#  ('amixem', 49),
#  ('fr', 49),
#  ('abc', 49),
#  ('Among Us', 49),
#  ('educational', 49),
#  ('NHL', 49),
#  ('K-POP', 49),
#  ('nikkie tutorials', 49),
#  ('math', 49),
#  ('shopping', 49),
#  ('among us logic', 49),
#  ('replay', 49),
#  ('talent', 49),
#  ('Drama', 49),
#  ('stand up', 49),
#  ('willian', 49),
#  ('film', 49),
#  ('best friends', 49),
#  ('songs', 49),
#  ('Transfer', 49),
#  ('gt', 49),
#  ('drawing', 48),
#  ('Scott Disick', 48),
#  ('complex', 48),
#  ('Among us', 48),
#  ('kristopher london', 48),
#  ('cake', 48),
#  ('fwf', 48),
#  ('마마무', 48),
#  ('LoL', 48),
#  ('mma news', 48),
#  ('MV', 48),
#  ('Lyrical Lemonade', 48),
#  ('free', 48),
#  ('college', 48),
#  ('multiplayer', 48),
#  ('Television', 48),
#  ('Toronto', 48),
#  ('top', 48),
#  ('New', 48),
#  ('performance', 48),
#  ('death', 48),
#  ('episode', 48),
#  ('슈가', 48),
#  ('제이홉', 48),
#  ('지민', 48),
#  ('정국', 48),
#  ('sketches', 48),
#  ('ben singer', 48),
#  ('how to apply makeup for beginners', 48),
#  ('chad james', 48),
#  ('faze rug', 47),
#  ('avatar', 47),
#  ('Riot Games', 47),
#  ('thomas petrou', 47),
#  ('manchester united', 47),
#  ('workout', 47),
#  ('lionel messi', 47),
#  ('tlc shows', 47),
#  ('apple event', 47),
#  ('Lovesick Girls', 47),
#  ('story time', 47),
#  ('tlc full episodes', 47),
#  ('Tyler Herro', 47),
#  ('gaethje', 47),
#  ('atlantic', 47),
#  ('아이캔트스탑미', 47),
#  ('funny among us', 47),
#  ('foreign love', 47),
#  ('international dating', 47),
#  ('marriage tv show', 47),
#  ('winner', 47),
#  ('green card marriage', 47),
#  ('musician', 47),
#  ('mother', 47),
#  ('Space', 46),
#  ('justin bieber', 46),
#  ('megan thee stallion', 46),
#  ('Mulatto', 46),
#  ('unus annus', 46),
#  ('the bachelorette', 46),
#  ('Twins', 46),
#  ('있지', 46),
#  ('epic', 46),
#  ('hacksmith', 46),
#  ('toronto', 46),
#  ('Review', 46),
#  ('2020 xxl freshman', 46),
#  ('disney', 46),
#  ('Xbox Series X', 46),
#  ('Science', 46),
#  ('nba 2020', 46),
#  ('max kellerman', 46),
#  ('Live', 46),
#  ('famous', 46),
#  ('Analysis', 46),
#  ('battle royale', 46),
#  ('nba finals', 46),
#  ('rosanna pansino', 46),
#  ('gadget', 46),
#  ('singing', 46),
#  ('Soundcloud Rap', 46),
#  ('faze jarvis', 46),
#  ('friendly', 46),
#  ('LeBron', 46),
#  ('first look', 46),
#  ('King James', 46),
#  ('koeman', 46),
#  ('father', 46),
#  ('Rajon Rondo', 46),
#  ('EA', 46),
#  ('talkshow', 46),
#  ("the dixie d'amelio show", 46),
#  ('NLE Choppa', 45),
#  ('Kardashians', 45),
#  ('BIGHIT', 45),
#  ('veritasium', 45),
#  ('C-SPAN', 45),
#  ('tom scott', 45),
#  ('man city', 45),
#  ('david', 45),
#  ('CSPAN', 45),
#  ('tv', 45),
#  ('among us meme', 45),
#  ('Juice WRLD', 45),
#  ('training', 45),
#  ('golden moustache', 45),
#  ('Day', 45),
#  ('Kendall Jenner', 45),
#  ('Kourtney Kardashian', 45),
#  ('iPhone', 45),
#  ('fatshow', 45),
#  ('Mark Goldbridge', 45),
#  ('los angeles', 45),
#  ('badass', 45),
#  ('Goldbridge', 45),
#  ('ucl', 45),
#  ('2020 xxl freshmen', 45),
#  ('cartoon animation', 45),
#  ('Manchester United live', 45),
#  ('freestyle', 45),
#  ('ultimate fighting championship', 45),
#  ('Keeping Up with the Kardashians', 45),
#  ('Kardashian', 45),
#  ('diego', 45),
#  ('KUWTK', 45),
#  ('goat', 45),
#  ('Jamal Murray', 45),
#  ('mu live streaming', 45),
#  ('cinematic', 45),
#  ('Houston Rockets', 45),
#  ('pop', 45),
#  ('real life among us', 45),
#  ('prom makeup', 45),
#  ('JuiceWRLD', 44),
#  ('sewing', 44),
#  ('vegan', 44),
#  ('Blizzard', 44),
#  ('ITZY', 44),
#  ('Chadwick Boseman', 44),
#  ('choreography', 44),
#  ('6ix9ine', 44),
#  ('batman', 44),
#  ('zackttg', 44),
#  ('zlatan', 44),
#  ('Hype House', 44),
#  ('ice cream', 44),
#  ('seek discomfort', 44),
#  ('mm7games', 44),
#  ('Kamala Harris', 44),
#  ('iphone 12 vs', 44),
#  ('ibrahimovic', 44),
#  ('new punjabi songs 2020', 44),
#  ('miami heat', 44),
#  ('HIPHOP', 44),
#  ('les parodie bros', 44),
#  ('MUFC', 44),
#  ('in real life', 44),
#  ('among', 44),
#  ('sketch comedy', 44),
#  ('알엠', 44),
#  ('nail art tutorial', 44),
#  ('뮤직비디오', 44),
#  ('shane madej', 44),
#  ('clippers', 44),
#  ('les parodie bro', 44),
#  ('les parodies bros', 44),
#  ('iphone 12 vs iphone 12 pro', 44),
#  ('culture', 44),
#  ('amazing', 44),
#  ('dab', 44),
#  ('Manchester United News', 44),
#  ('parodie bros', 44),
#  ('slow motion', 44),
#  ('parodie bro', 44),
#  ('parodies bro', 44),
#  ('parodies bros', 44),
#  ('Ribery', 44),
#  ('olivier', 44),
#  ('complex media', 44),
#  ('school', 44),
#  ('JIMIN', 44),
#  ('steven', 44),
#  ('demonstration', 44),
#  ('현진', 44),
#  ('Solskjaer', 44),
#  ('JUNGKOOK', 44),
#  ('JIN', 44),
#  ('Matt Stonie', 43),
#  ('Arsenal', 43),
#  ('pregnancy announcement', 43),
#  ('xbox series s', 43),
#  ('MAMAMOO', 43),
#  ('tesla', 43),
#  ('Sony', 43),
#  ('van halen', 43),
#  ('documentary', 43),
#  ('swap', 43),
#  ('sidemen sunday', 43),
#  ('Coronavirus', 43),
#  ('Megatoad', 43),
#  ('THE ALBUM', 43),
#  ('Liverpool', 43),
#  ('baby yoda', 43),
#  ('#sidemensunday', 43),
#  ('will smith', 43),
#  ('Japan', 43),
#  ('Competitive Eating', 43),
#  ('예지', 43),
#  ('Food Challenge', 43),
#  ('shots', 43),
#  ('MKBHD', 43),
#  ('khabib vs gaethje', 43),
#  ('리아', 43),
#  ('Speed Eating', 43),
#  ('teaser', 43),
#  ('Jam', 43),
#  ('아이즈와이드오픈', 43),
#  ('류진', 43),
#  ('premier league highlights', 43),
#  ('Eating Challenge', 43),
#  ('EPL', 43),
#  ('채령', 43),
#  ('유나', 43),
#  ('daily', 43),
#  ('return', 43),
#  ('eat the menu', 43),
#  ('vogue', 43),
#  ('transformation', 43),
#  ('first take nba', 43),
#  ('questions', 43),
#  ('DEATH BATTLE', 42),
#  ('engineering', 42),
#  ('jaiden', 42),
#  ('punjabi', 42),
#  ('mcdonalds', 42),
#  ('the voice', 42),
#  ('build', 42),
#  ('TXT', 42),
#  ('Dynamite', 42),
#  ('낫샤이', 42),
#  ('tomscott', 42),
#  ...]
